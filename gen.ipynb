# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH

def create_qa_list_document():
    doc = Document()
    
    # Настройка шрифта по умолчанию
    style = doc.styles['Normal']
    style.font.name = 'Times New Roman'
    style.font.size = Pt(11)
    
    # Заголовок
    title = doc.add_heading('Вопросы и ответы по учебнику "Essential English for IT Students. Part 2"', level=1)
    title.alignment = WD_ALIGN_PARAGRAPH.CENTER
    
    subtitle = doc.add_paragraph('Полные ответы на английском языке с переводом на русский')
    subtitle.alignment = WD_ALIGN_PARAGRAPH.CENTER
    doc.add_paragraph()

    # Данные: (Вопрос, Ответ EN, Перевод RU)
    qa_data = [
        ("What types of wired internet connections do you know? Talk about each of them in detail.",
         "There are three main types of wired internet connections: DSL uses telephone lines with digital signals and allows simultaneous voice and data transmission; Cable Internet uses coaxial TV cables and provides shared bandwidth among neighborhood users; Fiber-optic Internet uses light signals through glass fibers, offering the fastest speeds and low signal attenuation over long distances.",
         "Существует три основных типа проводных интернет-соединений: DSL использует телефонные линии с цифровыми сигналами и позволяет одновременную передачу голоса и данных; Кабельный Интернет использует коаксиальные ТВ-кабели и обеспечивает общую пропускную способность для пользователей района; Оптоволоконный Интернет использует световые сигналы через стеклянные волокна, предлагая максимальную скорость и низкое затухание сигнала на больших расстояниях."),
        
        ("What is the difference between DSL and dial-up connection?",
         "The main difference is that DSL uses higher frequency bands for data transmission, allowing simultaneous use of phone and Internet, while dial-up uses the same frequency for both voice and data, meaning you cannot use the phone and browse the Internet at the same time; additionally, DSL is always-on and significantly faster than dial-up.",
         "Основное различие заключается в том, что DSL использует более высокие частотные полосы для передачи данных, позволяя одновременное использование телефона и Интернета, тогда как коммутируемый доступ использует одну и ту же частоту для голоса и данных, что означает невозможность одновременного использования телефона и просмотра Интернета; кроме того, DSL работает постоянно и значительно быстрее коммутируемого доступа."),
        
        ("Talk about the three wireless internet access technologies mentioned in the text.",
         "The three wireless technologies are: Wi-Fi, which uses radio waves to connect devices locally and requires a wireless router; Satellite Internet, which allows access via geostationary satellites and works in remote areas but may experience latency due to long signal travel distances; and Cellular Internet, which uses cell towers with transceivers to provide network coverage, with different frequencies preventing interference between neighboring cells.",
         "Три беспроводные технологии: Wi-Fi, который использует радиоволны для подключения устройств локально и требует беспроводного роутера; Спутниковый Интернет, который обеспечивает доступ через геостационарные спутники и работает в удалённых районах, но может иметь задержку из-за большого расстояния прохождения сигнала; и Сотовый Интернет, который использует вышки с приёмо-передатчиками для обеспечения покрытия сети, причём разные частоты предотвращают помехи между соседними ячейками."),
        
        ("What are the three types of DSL connections that you know? Talk about each of them.",
         "The three types of DSL connections are: ADSL (Asymmetric DSL), where download speed is faster than upload speed; SDSL (Symmetric DSL), which provides equal upload and download speeds; and VDSL (Very-high-bit-rate DSL), which offers faster speeds but only over short distances from the exchange.",
         "Три типа DSL-соединений: ADSL (асимметричный DSL), где скорость скачивания выше скорости загрузки; SDSL (симметричный DSL), который обеспечивает равные скорости загрузки и скачивания; и VDSL (сверхвысокоскоростной DSL), который предлагает более высокие скорости, но только на коротких расстояниях от узла связи."),
        
        ("What is the difference between packet switching and circuit switching technologies?",
         "Circuit switching establishes a dedicated connection channel before communication starts and reserves the path even when idle, which can waste bandwidth; packet switching divides data into small packets that are routed independently through the network and reassembled at the destination, providing more efficient use of network resources.",
         "Коммутация каналов устанавливает выделенный канал связи до начала общения и резервирует путь даже в простое, что может приводить к неэффективному использованию пропускной способности; коммутация пакетов делит данные на небольшие пакеты, которые маршрутизируются независимо через сеть и собираются в пункте назначения, обеспечивая более эффективное использование сетевых ресурсов."),
        
        ("What are the two subtypes of packet switching technologies that you know? Talk about each of them.",
         "The two subtypes are: Datagram packet switching, where there is no dedicated channel and packets can be routed individually through different paths before being reassembled in order; and Virtual circuit switching, which is connection-oriented and first establishes a virtual path between source and destination, after which all packets follow this path sequentially.",
         "Два подтипа: Дейтаграммная коммутация пакетов, при которой нет выделенного канала и пакеты могут маршрутизироваться индивидуально по разным путям перед сборкой в правильном порядке; и Коммутация с виртуальной цепью, которая ориентирована на соединение и сначала устанавливает виртуальный путь между источником и получателем, после чего все пакеты следуют по этому пути последовательно."),
        
        ("Talk about the TCP/IP model (the layers, protocols).",
         "The TCP/IP model consists of four layers: the Application layer includes protocols like HTTP, FTP, and SMTP for user services; the Transport layer uses TCP for reliable delivery and UDP for fast, connectionless communication; the Internet layer uses IP for addressing and routing packets; and the Network Interface layer handles physical transmission using protocols like Ethernet.",
         "Модель TCP/IP состоит из четырёх уровней: Прикладной уровень включает протоколы вроде HTTP, FTP и SMTP для пользовательских сервисов; Транспортный уровень использует TCP для надёжной доставки и UDP для быстрой связи без установления соединения; Сетевой уровень использует IP для адресации и маршрутизации пакетов; и Канальный уровень отвечает за физическую передачу данных с использованием протоколов вроде Ethernet."),
        
        ("What is the difference between TCP and UDP?",
         "TCP (Transmission Control Protocol) guarantees data delivery through acknowledgements and retransmits lost packets, making it reliable but slower; UDP (User Datagram Protocol) does not verify connections or guarantee delivery, making it faster and suitable for real-time applications like voice calls, but less reliable.",
         "TCP (протокол управления передачей) гарантирует доставку данных через подтверждения и повторно отправляет потерянные пакеты, что делает его надёжным, но более медленным; UDP (протокол пользовательских дейтаграмм) не проверяет соединения и не гарантирует доставку, что делает его быстрее и подходящим для приложений реального времени, таких как голосовые звонки, но менее надёжным."),
        
        ("What is the difference between the Internet and the WWW?",
         "The Internet is a global network infrastructure that connects computers and devices worldwide, while the World Wide Web (WWW) is an information system that operates on the Internet, using hypertext and URLs to access interconnected documents and resources through web browsers.",
         "Интернет — это глобальная сетевая инфраструктура, соединяющая компьютеры и устройства по всему миру, тогда как Всемирная паутина (WWW) — это информационная система, работающая в Интернете и использующая гипертекст и URL-адреса для доступа к взаимосвязанным документам и ресурсам через веб-браузеры."),
        
        ("Talk about the three types of search engines and their distinctive features.",
         "The three types are: Crawler-based search engines, which automatically index content using programs called crawlers or spiders; Human-powered directories, which rely on human editors to manually review and categorize submitted websites; and Meta-search engines, which send queries to multiple search engines and compile the top results into one list without maintaining their own indexed database.",
         "Три типа: Поисковые системы на основе краулеров, которые автоматически индексируют контент с помощью программ, называемых краулерами или пауками; Ручные веб-каталоги, которые полагаются на человеческих редакторов для ручной проверки и категоризации представленных сайтов; и Метапоисковые системы, которые отправляют запросы в несколько поисковых систем и компилируют лучшие результаты в один список без ведения собственной базы индексов."),
        
        ("What are the three steps that every crawler-based search engine takes before displaying search results? Talk about each of these stages.",
         "The three steps are: Crawling, where special programs called spiders discover new and updated content by following links; Indexing, where the search engine processes and stores discovered content in a massive database, identifying keywords that describe each page; and Ranking, where the engine compares the user's query with indexed pages and orders results by relevance using complex algorithms.",
         "Три этапа: Сканирование, при котором специальные программы, называемые пауками, обнаруживают новый и обновлённый контент, переходя по ссылкам; Индексация, при которой поисковая система обрабатывает и хранит обнаруженный контент в огромной базе данных, определяя ключевые слова, описывающие каждую страницу; и Ранжирование, при котором система сравнивает запрос пользователя с проиндексированными страницами и упорядочивает результаты по релевантности с использованием сложных алгоритмов."),
        
        ("What makes meta-search engines different from other types of search engines?",
         "Meta-search engines are different because they do not maintain their own database of indexed pages; instead, they send user queries to several other search engines, remove duplicate results, and compile and rank the remaining results into one comprehensive list for the user.",
         "Метапоисковые системы отличаются тем, что не ведут собственную базу проиндексированных страниц; вместо этого они отправляют пользовательские запросы в несколько других поисковых систем, удаляют дублирующиеся результаты и компилируют и ранжируют оставшиеся результаты в один исчерпывающий список для пользователя."),
        
        ("What is the difference between crawler-based search engines and human-powered directories?",
         "Crawler-based search engines automatically discover and index actual webpage content using algorithms, while human-powered directories depend on manual submission and review by editors, matching user queries only with the short descriptions submitted by website owners rather than the full page content.",
         "Поисковые системы на основе краулеров автоматически обнаруживают и индексируют реальный контент веб-страниц с помощью алгоритмов, тогда как ручные веб-каталоги зависят от ручной подачи и проверки редакторами, сопоставляя пользовательские запросы только с короткими описаниями, представленными владельцами сайтов, а не с полным содержанием страниц."),
        
        ("What factors determine higher ranking in search results? What aspects can ranking algorithm take into consideration?",
         "Ranking algorithms consider multiple factors including keyword relevance and placement, the quality and quantity of backlinks pointing to a page, page load speed, mobile-friendliness, user engagement metrics, content freshness, and technical SEO elements such as proper URL structure and meta tags.",
         "Алгоритмы ранжирования учитывают множество факторов, включая релевантность и размещение ключевых слов, качество и количество обратных ссылок, указывающих на страницу, скорость загрузки страницы, адаптивность для мобильных устройств, метрики вовлечённости пользователей, свежесть контента и элементы технического SEO, такие как правильная структура URL и мета-теги."),
        
        ("What is the difference between a search engine and a web browser?",
         "A search engine operates on remote servers and indexes web content to help users find information by processing queries, while a web browser is local software installed on a user's device that decodes IP addresses, retrieves web pages, and renders HTML, CSS, and JavaScript to display content on the screen.",
         "Поисковая система работает на удалённых серверах и индексирует веб-контент, чтобы помочь пользователям находить информацию путём обработки запросов, тогда как веб-браузер — это локальное программное обеспечение, установленное на устройстве пользователя, которое декодирует IP-адреса, извлекает веб-страницы и отображает HTML, CSS и JavaScript для показа контента на экране."),
        
        ("Talk about any four search engines that can be used as an alternative to Google.",
         "Four alternatives to Google are: Bing, Microsoft's search engine with integrated tools and a rewards program; Baidu, the dominant search engine in China that is heavily censored; Yandex, the leading search engine in Russia with user-friendly features and additional services; and Ecosia, a CO2-neutral search engine that uses advertising revenue to plant trees.",
         "Четыре альтернативы Google: Bing — поисковая система Microsoft с интегрированными инструментами и программой вознаграждений; Baidu — доминирующая поисковая система в Китае, подверженная строгой цензуре; Yandex — ведущая поисковая система в России с удобным интерфейсом и дополнительными сервисами; и Ecosia — углеродно-нейтральная поисковая система, которая использует доходы от рекламы для посадки деревьев."),
        
        ("How can programming languages be classified? Provide examples and talk about the distinctive features of each type you have named.",
         "Programming languages can be classified into low-level languages, such as machine code and assembly, which are close to hardware, complex, and machine-specific; and high-level languages, such as Python, Java, and C++, which use English-like syntax, are portable across different platforms, and are easier for humans to write and debug.",
         "Языки программирования можно классифицировать на низкоуровневые языки, такие как машинный код и ассемблер, которые близки к аппаратному обеспечению, сложны и зависят от конкретной машины; и высокоуровневые языки, такие как Python, Java и C++, которые используют синтаксис, близкий к английскому, переносимы между разными платформами и проще для написания и отладки человеком."),
        
        ("What is OOP? What are the three key features of OOP? Talk about each of them in detail.",
         "OOP (Object-Oriented Programming) is a programming paradigm that uses objects containing both data and methods. Its three key features are: Encapsulation, which bundles data and instructions into modular objects; Inheritance, which allows specific classes to automatically acquire properties from more general classes; and Polymorphism, which enables different objects to respond differently to the same instruction based on their type.",
         "ООП (объектно-ориентированное программирование) — это парадигма программирования, использующая объекты, содержащие как данные, так и методы. Его три ключевые особенности: Инкапсуляция, которая объединяет данные и инструкции в модульные объекты; Наследование, которое позволяет конкретным классам автоматически приобретать свойства более общих классов; и Полиморфизм, который позволяет разным объектам по-разному реагировать на одну и ту же инструкцию в зависимости от их типа."),
        
        ("What is the difference between a compiler, an interpreter, and an assembler?",
         "A compiler translates the entire source code written in a high-level language into machine code in one go before execution; an interpreter translates and executes the source code line by line during runtime; and an assembler converts assembly language, which uses symbolic abbreviations, into binary machine code that the computer can directly execute.",
         "Компилятор переводит весь исходный код, написанный на языке высокого уровня, в машинный код за один раз перед выполнением; интерпретатор переводит и выполняет исходный код построчно во время выполнения программы; а ассемблер преобразует язык ассемблера, использующий символьные сокращения, в двоичный машинный код, который компьютер может выполнять напрямую."),
        
        ("What are the three main tools used in web design? Talk about each of them.",
         "The three main tools are: HTML (Hypertext Markup Language), which structures webpage content using tags for elements like headings, paragraphs, and images; CSS (Cascading Style Sheets), which defines the visual styling, layout, colors, and fonts of web pages; and JavaScript, which adds interactivity and dynamic behavior to webpages, such as animations, pop-up menus, and form validation.",
         "Три основных инструмента: HTML (язык гипертекстовой разметки), который структурирует контент веб-страниц с помощью тегов для элементов вроде заголовков, абзацев и изображений; CSS (каскадные таблицы стилей), которые определяют визуальное оформление, макет, цвета и шрифты веб-страниц; и JavaScript, который добавляет интерактивность и динамическое поведение веб-страницам, например анимации, всплывающие меню и проверку форм."),
        
        ("What is the difference between frontend and backend web development?",
         "Frontend development focuses on the client-side, visible part of a website that users interact with directly, using HTML, CSS, and JavaScript; backend development handles the server-side operations, including data processing, database management, and application logic, using languages like Python, Java, PHP, and SQL.",
         "Frontend-разработка фокусируется на клиентской, видимой части веб-сайта, с которой пользователи взаимодействуют напрямую, используя HTML, CSS и JavaScript; backend-разработка занимается серверными операциями, включая обработку данных, управление базами данных и логику приложений, используя такие языки, как Python, Java, PHP и SQL."),
        
        ("What are the advantages and disadvantages of using website builders?",
         "Advantages include no need for coding knowledge, ready-made professional templates, drag-and-drop functionality, and fast, affordable website creation; disadvantages include limited customization options, restrictions on free plans, potential performance issues, and vendor lock-in that makes migrating to another platform difficult.",
         "Преимущества включают отсутствие необходимости в знаниях программирования, готовые профессиональные шаблоны, функциональность перетаскивания, а также быстрое и доступное создание сайтов; недостатки включают ограниченные возможности кастомизации, ограничения бесплатных тарифов, потенциальные проблемы с производительностью и привязку к платформе, что затрудняет переход на другую систему."),
        
        ("What is SEO? What is its main purpose?",
         "SEO (Search Engine Optimization) is a set of improvements and techniques applied to a website to help it rank higher in search engine results pages; its main purpose is to attract more organic (unpaid) traffic by increasing the website's visibility and relevance for user queries.",
         "SEO (поисковая оптимизация) — это набор улучшений и методов, применяемых к веб-сайту, чтобы помочь ему занять более высокие позиции в результатах поиска; его основная цель — привлекать больше органического (бесплатного) трафика за счёт повышения видимости и релевантности сайта для пользовательских запросов."),
        
        ("What is the difference between on-page SEO and off-page SEO?",
         "On-page SEO involves optimizing elements within your own website, such as content quality, keyword usage, meta tags, and internal linking structure; off-page SEO focuses on building the website's authority and reputation externally through backlinks, social media signals, and brand mentions on other sites.",
         "Внутренний SEO (on-page) включает оптимизацию элементов внутри вашего собственного сайта, таких как качество контента, использование ключевых слов, мета-теги и структура внутренних ссылок; внешний SEO (off-page) фокусируется на повышении авторитета и репутации сайта извне через обратные ссылки, сигналы из социальных сетей и упоминания бренда на других сайтах."),
        
        ("What is meant by \"organic results\"?",
         "Organic results are search engine listings that appear based on their relevance to the user's query and the search engine's ranking algorithms, not because the website owner paid for advertising; they are earned through effective SEO practices rather than purchased.",
         "Органические результаты — это позиции в поисковой выдаче, которые появляются на основе их релевантности запросу пользователя и алгоритмов ранжирования поисковой системы, а не потому, что владелец сайта заплатил за рекламу; они зарабатываются благодаря эффективным практикам SEO, а не покупаются."),
        
        ("What is malware? What types of malware do you know? Talk about each one in detail.",
         "Malware is malicious software designed to harm devices, steal data, or gain unauthorized access. Types include: Viruses, which infect host programs and replicate; Worms, standalone programs that spread via networks; Trojans, which disguise as legitimate software to create backdoors; Ransomware, which encrypts data and demands payment; Spyware/Keyloggers, which collect user data secretly; Adware, which displays unwanted ads; and Miners, which hijack computing resources for cryptocurrency mining.",
         "Вредоносное ПО (malware) — это злонамеренное программное обеспечение, предназначенное для нанесения вреда устройствам, кражи данных или получения несанкционированного доступа. Типы включают: Вирусы, которые заражают программы-хозяева и размножаются; Черви, самостоятельные программы, распространяющиеся по сетям; Трояны, которые маскируются под легитимное ПО для создания бэкдоров; Шифровальщики, которые шифруют данные и требуют выкуп; Шпионское ПО/Кейлоггеры, которые тайно собирают данные пользователя; Рекламное ПО, которое показывает нежелательную рекламу; и Майнеры, которые захватывают вычислительные ресурсы для добычи криптовалют."),
        
        ("What are the four routines of a virus? Talk about the function of each of them.",
         "The four routines are: Misdirection routine, which hides the virus's presence to avoid detection; Reproduction routine, which copies the virus code into other programs or files; Trigger, which activates the payload at a specific time or when a particular event occurs; and Payload, which performs the malicious action, such as displaying a message, deleting files, or damaging the system.",
         "Четыре процедуры: Процедура дезориентации, которая скрывает присутствие вируса, чтобы избежать обнаружения; Процедура самокопирования, которая копирует код вируса в другие программы или файлы; Триггер, который активирует вредоносную часть в определённое время или при наступлении конкретного события; и Полезная нагрузка, которая выполняет вредоносное действие, например показывает сообщение, удаляет файлы или повреждает систему."),
        
        ("What types of cybercrime do you know? Talk about each of them.",
         "Types of cybercrime include: Phishing, sending fake messages to steal credentials; Defacement, changing a website's appearance for ideological reasons; Salami shaving, stealing tiny amounts from many accounts to avoid detection; Piggybacking, gaining unauthorized wireless network access; Software piracy, illegally copying and distributing software; and DDoS attacks, overwhelming a target with traffic from multiple sources to disrupt services.",
         "Типы киберпреступлений включают: Фишинг — отправка фальшивых сообщений для кражи учётных данных; Дефейсмент — изменение внешнего вида сайта по идеологическим причинам; «Салями» — кража крошечных сумм со множества счетов для избежания обнаружения; «Подключение к чужому» — получение несанкционированного доступа к беспроводной сети; Пиратство ПО — незаконное копирование и распространение программного обеспечения; и DDoS-атаки — перегрузка цели трафиком из множества источников для нарушения работы сервисов."),
        
        ("What is the difference between a virus and a worm?",
         "A virus requires a host program and user activation to spread, as it attaches itself to files and executes when the user runs the infected program; a worm is a standalone program that can self-replicate and spread automatically across networks without human intervention or a host file.",
         "Вирус требует программы-хозяина и активации пользователем для распространения, так как он прикрепляется к файлам и выполняется, когда пользователь запускает заражённую программу; червь — это самостоятельная программа, которая может саморазмножаться и распространяться автоматически по сетям без вмешательства человека или файла-хозяина."),
        
        ("What is the difference between a virus and a Trojan?",
         "A virus replicates itself by infecting other files and programs, spreading from one system to another; a Trojan does not replicate but disguises itself as useful or legitimate software to trick users into installing it, after which it creates a backdoor for unauthorized access or performs other malicious actions.",
         "Вирус размножается, заражая другие файлы и программы, и распространяется с одной системы на другую; троян не размножается, но маскируется под полезное или легитимное программное обеспечение, чтобы обманом заставить пользователей установить его, после чего создаёт бэкдор для несанкционированного доступа или выполняет другие вредоносные действия."),
        
        ("What is the difference between DoS and DDoS attack? How is DDoS attack performed?",
         "A DoS (Denial of Service) attack comes from a single source attempting to overwhelm a target with traffic, while a DDoS (Distributed Denial of Service) attack uses multiple compromised devices, often forming a botnet, to flood the target simultaneously from many locations; a DDoS attack is performed by a hacker who first infects many devices with malware to create a botnet, then controls them remotely and commands all devices to send traffic to the target at once, overwhelming its resources.",
         "Атака DoS (отказ в обслуживании) исходит из одного источника, пытающегося перегрузить цель трафиком, тогда как атака DDoS (распределённый отказ в обслуживании) использует множество скомпрометированных устройств, часто образующих ботнет, для одновременной перегрузки цели из множества мест; атака DDoS выполняется хакером, который сначала заражает множество устройств вредоносным ПО для создания ботнета, затем управляет ими удалённо и командует всем устройствам одновременно отправлять трафик на цель, перегружая её ресурсы."),
        
        ("What is firewall? What can firewall filters be based on?",
         "A firewall is a software or hardware security system that monitors and controls incoming and outgoing network traffic based on predetermined security rules; firewall filters can be based on IP addresses, domain names, port numbers, specific keywords or phrases, and communication protocols, allowing administrators to block or permit access according to organizational security policies.",
         "Файрвол — это программная или аппаратная система безопасности, которая отслеживает и контролирует входящий и исходящий сетевой трафик на основе заранее определённых правил безопасности; фильтры файрвола могут основываться на IP-адресах, доменных именах, номерах портов, конкретных ключевых словах или фразах, а также протоколах связи, позволяя администраторам блокировать или разрешать доступ в соответствии с политиками безопасности организации."),
        
        ("What is the difference between signature-based scanning and heuristic scanning?",
         "Signature-based scanning matches file code patterns against a database of known malware signatures to identify threats, which is effective for detecting known malware but cannot identify new variants; heuristic scanning uses rules, algorithms, and behavioral analysis to detect suspicious code patterns or activities, allowing it to identify new or previously unknown malware variants, though it may sometimes produce false positives.",
         "Сканирование на основе сигнатур сопоставляет паттерны кода файлов с базой данных известных сигнатур вредоносного ПО для выявления угроз, что эффективно для обнаружения известного вредоносного ПО, но не может выявить новые варианты; эвристическое сканирование использует правила, алгоритмы и анализ поведения для обнаружения подозрительных паттернов кода или действий, что позволяет выявлять новые или ранее неизвестные варианты вредоносного ПО, хотя иногда может давать ложные срабатывания."),
        
        ("What is a signature?",
         "A signature is a unique code pattern or digital fingerprint that distinguishes a specific virus or malware program from other software, and it is used by antivirus programs to identify and detect known malicious code by comparing file contents against a database of stored signatures.",
         "Сигнатура — это уникальный паттерн кода или цифровой отпечаток, который отличает конкретный вирус или вредоносную программу от другого программного обеспечения, и она используется антивирусными программами для идентификации и обнаружения известного вредоносного кода путём сравнения содержимого файлов с базой данных сохранённых сигнатур."),
        
        ("What are the two main types of encryption? What is the difference between the two?",
         "The two main types are symmetric encryption, where the same secret key is used for both encryption and decryption and must be kept secret by all parties, and asymmetric encryption, where a public key encrypts data and a mathematically related private key decrypts it; the key difference is that symmetric encryption requires secure key exchange beforehand, while asymmetric encryption allows secure communication without pre-sharing a secret key.",
         "Два основных типа: симметричное шифрование, при котором один и тот же секретный ключ используется как для шифрования, так и для дешифрования и должен храниться в секрете всеми сторонами, и асимметричное шифрование, при котором открытый ключ шифрует данные, а математически связанный с ним закрытый ключ дешифрует их; ключевое различие в том, что симметричное шифрование требует предварительного безопасного обмена ключом, тогда как асимметричное шифрование позволяет безопасную связь без предварительного обмена секретным ключом."),
        
        ("What two methods of breaking a cipher are there?",
         "The two methods are brute force, which involves systematically trying random keys until the correct one is found, and cryptanalysis, which involves finding and exploiting a weakness or flaw in the cipher algorithm itself to decrypt the message without knowing the key; brute force relies on computing power, while cryptanalysis relies on mathematical insight.",
         "Два метода: перебор, который предполагает систематическую пробу случайных ключей до нахождения правильного, и криптоанализ, который предполагает поиск и использование слабости или изъяна в самом алгоритме шифра для дешифрования сообщения без знания ключа; перебор опирается на вычислительную мощность, тогда как криптоанализ опирается на математическое понимание."),
        
        ("What is a CAPTCHA? Where is this tool implemented?",
         "CAPTCHA (Completely Automated Public Turing test to tell Computers and Humans Apart) is a challenge, such as distorted text or image selection, designed to verify that the user is human and not an automated bot; it is commonly implemented on registration forms, login pages, comment sections, and other areas where user input needs to be verified to prevent spam and automated attacks.",
         "CAPTCHA (полностью автоматизированный публичный тест Тьюринга для различения компьютеров и людей) — это проверка, например, искажённый текст или выбор изображений, предназначенная для подтверждения, что пользователь — человек, а не автоматический бот; она обычно используется в формах регистрации, на страницах входа, в разделах комментариев и других местах, где требуется проверка пользовательского ввода для предотвращения спама и автоматических атак."),
        
        ("What is the Turing test? Talk about its procedure.",
         "The Turing test is a method for determining whether a machine can exhibit intelligent behavior indistinguishable from a human; its procedure involves an interrogator who communicates via text with both a hidden human and a hidden machine, asking questions to both, and if the interrogator cannot reliably distinguish the machine from the human (accuracy below 50%), the machine is considered to have passed the test and demonstrated human-like intelligence.",
         "Тест Тьюринга — это метод определения того, может ли машина демонстрировать интеллектуальное поведение, неотличимое от человеческого; его процедура включает экзаменатора, который общается через текст как со скрытым человеком, так и со скрытой машиной, задавая вопросы обоим, и если экзаменатор не может надёжно отличить машину от человека (точность ниже 50%), считается, что машина прошла тест и продемонстрировала интеллект, подобный человеческому."),
        
        ("What is the difference between classification and clustering?",
         "Classification is a supervised learning task where data is assigned to predefined, known categories based on labeled training examples, while clustering is an unsupervised learning task where data is grouped into undefined categories based solely on similarities and patterns within the data itself, without prior knowledge of the categories.",
         "Классификация — это задача обучения с учителем, при которой данные присваиваются предопределённым, известным категориям на основе размеченных обучающих примеров, тогда как кластеризация — это задача обучения без учителя, при которой данные группируются в неопределённые категории исключительно на основе сходства и закономерностей внутри самих данных, без предварительного знания категорий."),
        
        ("What is backpropagation?",
         "Backpropagation is a feedback learning algorithm used in neural networks where the difference between the network's actual output and the intended output is calculated, and this error signal is propagated backward through the network to adjust the weights of connections between neurons, gradually reducing errors and improving the network's accuracy over time through iterative training.",
         "Обратное распространение ошибки (backpropagation) — это алгоритм обучения с обратной связью, используемый в нейронных сетях, при котором вычисляется разница между фактическим выходом сети и желаемым выходом, и этот сигнал ошибки распространяется назад через сеть для корректировки весов связей между нейронами, постепенно уменьшая ошибки и повышая точность сети со временем посредством итеративного обучения."),
        
        ("What is an artificial neural network? What tasks can neural networks accomplish?",
         "An artificial neural network is a computing system inspired by biological brains, consisting of interconnected artificial neurons (nodes) that process information using mathematical equations and weighted connections; neural networks can accomplish tasks such as face recognition, autonomous driving, computer-generated imagery, machine translation, fraud detection, classification, clustering, and predictive analytics by learning patterns from large datasets.",
         "Искусственная нейронная сеть — это вычислительная система, вдохновлённая биологическими мозгами, состоящая из взаимосвязанных искусственных нейронов (узлов), которые обрабатывают информацию с использованием математических уравнений и взвешенных связей; нейронные сети могут выполнять такие задачи, как распознавание лиц, автономное вождение, компьютерная графика, машинный перевод, обнаружение мошенничества, классификация, кластеризация и прогнозная аналитика, обучаясь закономерностям на больших наборах данных."),
        
        ("In what way is an artificial neural network similar to biological brain? Describe the structure of artificial neural networks.",
         "Artificial neural networks are similar to biological brains in that both use interconnected nodes (neurons) where connection strengths (weights) affect signal transmission, similar to synapses; the structure typically consists of input units that receive data, one or more layers of hidden units that process information, and output units that produce results, with fully connected layers where each unit connects to every unit in the next layer through weighted connections.",
         "Искусственные нейронные сети похожи на биологические мозги тем, что обе используют взаимосвязанные узлы (нейроны), где сила связей (веса) влияет на передачу сигналов, аналогично синапсам; структура обычно состоит из входных узлов, которые получают данные, одного или нескольких слоёв скрытых узлов, которые обрабатывают информацию, и выходных узлов, которые выдают результаты, причём слои полностью связаны, и каждый узел соединяется с каждым узлом следующего слоя через взвешенные соединения."),
        
        ("Why are neural networks compared to 'black boxes'?",
         "Neural networks are compared to black boxes because users can input data and receive outputs, but the internal decision-making process—how specific weights, connections, and activations produce a particular result—is complex, non-transparent, and difficult for humans to interpret or explain, making it challenging to understand exactly why the network made a specific decision.",
         "Нейронные сети сравнивают с «чёрными ящиками», потому что пользователи могут вводить данные и получать результаты, но внутренний процесс принятия решений — как конкретные веса, связи и активации приводят к определённому результату — является сложным, непрозрачным и трудным для интерпретации или объяснения человеком, что затрудняет понимание того, почему именно сеть приняла конкретное решение."),
        
        ("What is IoT? What are the major problems in using the IoT technology?",
         "IoT (Internet of Things) is a system of interrelated physical objects, animals, or people equipped with unique identifiers and the ability to transfer data over a network without human interaction; major problems include increased security risks due to more entry points for hackers, challenges in managing massive volumes of data, the risk that a single bug could corrupt an entire connected system, and the lack of international compatibility standards between devices from different manufacturers.",
         "IoT (Интернет вещей) — это система взаимосвязанных физических объектов, животных или людей, оснащённых уникальными идентификаторами и способностью передавать данные по сети без участия человека; основные проблемы включают повышенные риски безопасности из-за большего количества точек входа для хакеров, сложности управления огромными объёмами данных, риск того, что одна ошибка может повредить всю подключённую систему, и отсутствие международных стандартов совместимости между устройствами разных производителей."),
        
        ("What is HLAI? What are the risks of using HLAI?",
         "HLAI (Human-like Artificial Intelligence) refers to AI systems designed to match or mimic human intelligence; risks include workers losing economic and political bargaining power as machines substitute human labor, increased societal dependency on those who control the technology, and the potential loss of human control if AI systems mimic rather than augment human capabilities, potentially leading to unintended consequences.",
         "HLAI (искусственный интеллект, подобный человеку) относится к системам ИИ, разработанным для соответствия или имитации человеческого интеллекта; риски включают потерю работниками экономической и политической власти по мере замены человеческого труда машинами, рост зависимости общества от тех, кто контролирует технологии, и потенциальную потерю человеческого контроля, если системы ИИ имитируют, а не дополняют человеческие возможности, что потенциально может привести к непредвиденным последствиям.")
    ]

    # Заполняем документ в формате списка
    for idx, (question, answer_en, answer_ru) in enumerate(qa_data, 1):
        # Вопрос жирным
        p_question = doc.add_paragraph()
        run_q = p_question.add_run(f"{idx}. {question}")
        run_q.bold = True
        run_q.font.size = Pt(12)
        
        # Ответ на английском
        p_answer = doc.add_paragraph()
        p_answer.add_run("Answer: ").bold = True
        p_answer.add_run(answer_en)
        
        # Перевод
        p_translation = doc.add_paragraph()
        p_translation.add_run("Перевод: ").bold = True
        p_translation.add_run(answer_ru)
        
        # Разделитель
        doc.add_paragraph("─" * 80)

    # Сохраняем файл
    output_filename = "IT_Questions_List.docx"
    doc.save(output_filename)
    print(f"✅ Файл '{output_filename}' успешно создан!")

if __name__ == "__main__":
    create_qa_list_document()
# Out:
# ✅ Файл 'IT_Questions_List.docx' успешно создан!
